# %% [markdown]
# # Dataset Sloan Digital Sky Survey DR14
# ## Data Clean

# %%
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pyplot as figure

# %%
data = pd.read_csv("./dataset.txt",sep=",")
data_new = pd.read_csv("./dataset.txt",sep=",")

# %%
data.head()
# Out:
#           objid          ra       dec         u         g         r         i  \
# 0  1.237650e+18  183.531326  0.089693  19.47406  17.04240  15.94699  15.50342
# 1  1.237650e+18  183.598371  0.135285  18.66280  17.21449  16.67637  16.48922
# 2  1.237650e+18  183.680207  0.126185  19.38298  18.19169  17.47428  17.08732
# 3  1.237650e+18  183.870529  0.049911  17.76536  16.60272  16.16116  15.98233
# 4  1.237650e+18  183.883288  0.102557  17.55025  16.26342  16.43869  16.55492
#
#           z  run  rerun  camcol  field     specobjid   class  redshift  plate  \
# 0  15.22531  752    301       4    267  3.722360e+18    STAR -0.000009   3306
# 1  16.39150  752    301       4    267  3.638140e+17    STAR -0.000055    323
# 2  16.80125  752    301       4    268  3.232740e+17  GALAXY  0.123111    287
# 3  15.90438  752    301       4    269  3.722370e+18    STAR -0.000111   3306
# 4  16.61326  752    301       4    269  3.722370e+18    STAR  0.000590   3306
#
#      mjd  fiberid
# ...

# %% [markdown]
# ## Entendiendo los datos en este caso cada columna su significado y poder hacer inferencias.

# %%
columns_names = data.columns.values.tolist()
columns_names
# Out:
# ['objid',
#  'ra',
#  'dec',
#  'u',
#  'g',
#  'r',
#  'i',
#  'z',
#  'run',
#  'rerun',
#  'camcol',
#  'field',
#  'specobjid',
#  'class',
#  'redshift',
#  'plate',
#  'mjd',
#  'fiberid']

# %%
dummy_class = pd.get_dummies(data["class"])
dummy_class
# Out:
#       GALAXY  QSO  STAR
# 0          0    0     1
# 1          0    0     1
# 2          1    0     0
# 3          0    0     1
# 4          0    0     1
# ...      ...  ...   ...
# 9995       1    0     0
# 9996       1    0     0
# 9997       0    0     1
# 9998       1    0     0
# 9999       1    0     0
#
# [10000 rows x 3 columns]

# %%
data = data.drop(["class"],axis=1)
data =pd.concat([data,dummy_class],axis=1)

# %%
data
# Out:
#              objid          ra        dec         u         g         r  \
# 0     1.237650e+18  183.531326   0.089693  19.47406  17.04240  15.94699
# 1     1.237650e+18  183.598371   0.135285  18.66280  17.21449  16.67637
# 2     1.237650e+18  183.680207   0.126185  19.38298  18.19169  17.47428
# 3     1.237650e+18  183.870529   0.049911  17.76536  16.60272  16.16116
# 4     1.237650e+18  183.883288   0.102557  17.55025  16.26342  16.43869
# ...            ...         ...        ...       ...       ...       ...
# 9995  1.237650e+18  131.316413  51.539547  18.81777  17.47053  16.91508
# 9996  1.237650e+18  131.306083  51.671341  18.27255  17.43849  17.07692
# 9997  1.237650e+18  131.552562  51.666986  18.75818  17.77784  17.51872
# 9998  1.237650e+18  131.477151  51.753068  18.88287  17.91068  17.53152
# 9999  1.237650e+18  131.665012  51.805307  19.27586  17.37829  16.30542
#
#              i         z   run  rerun  camcol  field     specobjid  redshift  \
# ...

# %%
dfg = dummy_class["GALAXY"]
dfg.replace({1:'2',0:'0'})

df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-0fa8fc752820> in <module>
#       2 dfg.replace({1:'2',0:'0'})
#       3
# ----> 4 df
#
# NameError: name 'df' is not defined

# %%
#recortar los datos

# %%
import seaborn as sns
sns.countplot(x="class",data=data_new)
plt.show()

# %% [markdown]
# #### como podemos observar una relacion entre la clase y el campo, nos dice exactamente a lo que pertenece.

# %%
pd.crosstab(data["field"].values,data["class"].values).plot(kind="bar")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
pd.crosstab(data["redshift"].values,data["class"].values).plot(kind="bar")

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
c = 1+ np.log2(10000)
plt.hist(data["QSO"], bins=int(np.ceil(c))) #bins  = [0,30,60,...]
plt.xlabel("datos astronomicos")
plt.ylabel("Frecuencia")
plt.title("histograma del datos astronomicos de una star")
# Out:
# Text(0.5, 1.0, 'histograma del datos astronomicos de una star')

# %%
data1 = data[data["QSO"]!=0]
data1.head()
# Out:
#            objid          ra       dec         u         g         r  \
# 15  1.237650e+18  184.350647  0.207230  18.73832  18.60962  18.39696
# 17  1.237650e+18  184.245664  0.198257  19.22143  19.30248  19.13823
# 22  1.237650e+18  184.654170  0.122673  19.07731  18.64518  18.49678
# 45  1.237650e+18  185.164376  0.074358  17.55001  17.42367  17.35734
# 62  1.237650e+18  160.384806 -0.586705  19.52565  19.29625  18.95885
#
#            i         z  run  rerun  camcol  field     specobjid  redshift  \
# 15  18.31174  17.97663  752    301       4    272  3.232950e+17  0.271937
# 17  19.11351  19.23454  752    301       4    272  3.232940e+17  1.178098
# 22  18.52677  18.45765  752    301       4    274  3.243750e+17  0.925173
# 45  17.19343  16.97589  752    301       4    278  3.244010e+17  2.044347
# 62  18.52108  18.57694  756    301       2    298  3.097000e+17  0.134643
#
#     plate    mjd  fiberid  GALAXY  QSO  STAR
# 15    287  52023      587       0    1     0
# ...

# %%
data12 = data[data["STAR"]!=0]
data12.shape
# Out:
# (4152, 20)

# %%
data123  =data[data["GALAXY"]!=0]
data123.shape
# Out:
# (4998, 20)

# %%
data_intersection=data[(data["GALAXY"]!=0) & (data["STAR"]!=0) ]
data_intersection.shape
# Out:
# (0, 20)

# %%
data.describe()
# Out:
#               objid            ra           dec             u             g  \
# count  1.000000e+04  10000.000000  10000.000000  10000.000000  10000.000000
# mean   1.237650e+18    175.529987     14.836148     18.619355     17.371931
# std    1.577039e+05     47.783439     25.212207      0.828656      0.945457
# min    1.237650e+18      8.235100     -5.382632     12.988970     12.799550
# 25%    1.237650e+18    157.370946     -0.539035     18.178035     16.815100
# 50%    1.237650e+18    180.394514      0.404166     18.853095     17.495135
# 75%    1.237650e+18    201.547279     35.649397     19.259232     18.010145
# max    1.237650e+18    260.884382     68.542265     19.599900     19.918970
#
#                   r             i             z           run    rerun  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.0
# mean      16.840963     16.583579     16.422833    981.034800    301.0
# ...

# %%
data.groupby("class").mean()
# Out:
#                objid          ra        dec          u          g          r  \
# class
# GALAXY  1.237650e+18  177.333570  15.764372  18.804339  17.350216  16.649506
# QSO     1.237650e+18  177.468000  20.570639  18.942928  18.678714  18.498535
# STAR    1.237650e+18  172.962158  12.544824  18.330439  17.130547  16.732093
#
#                 i          z          run  rerun    camcol       field  \
# class
# GALAXY  16.272770  16.017923   996.711685  301.0  3.654662  300.963585
# QSO     18.360007  18.274761  1036.120000  301.0  3.694118  304.983529
# STAR    16.594047  16.531119   950.886561  301.0  3.632225  303.552264
#
#            specobjid  redshift        plate           mjd     fiberid
# class
# GALAXY  5.379141e+17  0.080325   477.680672  52030.280912  340.108844
# QSO     1.447231e+18  1.218366  1285.305882  52694.289412  381.558824
# STAR    3.018202e+18  0.000043  2680.613198  54093.892823  362.838391

# %%
figure, axs = plt.subplots(4,4, sharey=True,sharex=True)
data.plot(kind="scatter", x="ra", y = "dec", ax=axs[0][0])
data.plot(kind="scatter",x="ra", y="g", ax=axs[0][1])
data.plot(kind="scatter",x="ra", y="i", ax=axs[0][2])
data.plot(kind="scatter",x="ra", y="z", ax=axs[0][3])

data.plot(kind="scatter",x="redshift", y="dec", ax=axs[1][0])
data.plot(kind="scatter",x="redshift", y="g", ax=axs[1][1])
data.plot(kind="scatter",x="redshift", y="i", ax=axs[1][2])
data.plot(kind="scatter",x="redshift", y="z", ax=axs[1][3])

data.plot(kind="scatter",x="plate", y="dec", ax=axs[2][0])
data.plot(kind="scatter",x="plate", y="g", ax=axs[2][1])
data.plot(kind="scatter",x="plate", y="i", ax=axs[2][2])
data.plot(kind="scatter",x="plate", y="z", ax=axs[2][3])
data.plot(kind="scatter",x="plate", y="dec", ax=axs[2][0])
data.plot(kind="scatter",x="plate", y="g", ax=axs[2][1])
data.plot(kind="scatter",x="plate", y="i", ax=axs[2][2])
data.plot(kind="scatter",x="plate", y="z", ax=axs[2][3])
